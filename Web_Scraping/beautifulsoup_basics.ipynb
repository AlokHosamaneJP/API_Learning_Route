# %%
from bs4 import BeautifulSoup
import requests
# Out:
# Requirement already satisfied: requests in /Users/alokjp/Desktop/API_Learning_Route-1/.venv/lib/python3.13/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/alokjp/Desktop/API_Learning_Route-1/.venv/lib/python3.13/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alokjp/Desktop/API_Learning_Route-1/.venv/lib/python3.13/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alokjp/Desktop/API_Learning_Route-1/.venv/lib/python3.13/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alokjp/Desktop/API_Learning_Route-1/.venv/lib/python3.13/site-packages (from requests) (2026.1.4)

# %%
url = 'https://en.wikipedia.org/wiki/IBM'

reponse = requests.get()

html_content = response.text

soup = BeautifulSoup(html_content, 'html.parser')

print(html_content[:100])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 url = 'https://en.wikipedia.org/wiki/IBM'
# ----> 3 reponse = requests.get()
#       5 html_content = response.text
#       7 soup = BeautifulSoup(html_content, 'html.parser')
#
# TypeError: get() missing 1 required positional argument: 'url'
